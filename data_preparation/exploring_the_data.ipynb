# %%
from unirefs_from_genefams import unirefs_from_tsv
from uniprot_parsing import parse_unirefs

# %%
genefamilies_file = "/Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/data/genefamilies_fragment.tsv"

# %%
uniclust2uniref = "/Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/data/mini_uniref_mapping.tsv"

# %%
unirefs = unirefs_from_tsv(genefamilies_file, uniclust2uniref)
# Out:
# 2 UniClust90s was/were not matched

# %%
df = parse_unirefs(unirefs)
# Out:
# Fetching UniProt data:   0%|                              | 0/6 [00:00<?, ?it/s]
# Fetching  UNK9228
# Fetching UniProt data:  17%|███▋                  | 1/6 [00:01<00:09,  1.98s/it]
# Fetching  A0A016ASE6
# Fetching UniProt data:  33%|███████▎              | 2/6 [00:03<00:06,  1.65s/it]
# Fetching  B6XW19
# Fetching UniProt data:  50%|███████████           | 3/6 [00:04<00:04,  1.53s/it]
# Fetching  A0A173X055
# Fetching UniProt data:  67%|██████████████▋       | 4/6 [00:06<00:02,  1.46s/it]
# Fetching  R7E436
# Fetching UniProt data:  83%|██████████████████▎   | 5/6 [00:07<00:01,  1.45s/it]
# Fetching  A0A087AYU9
# Fetching UniProt data: 100%|██████████████████████| 6/6 [00:08<00:00,  1.49s/it]
# Finished parsing

# %%
df
# Out:
#                      0.entryType 0.primaryAccession  \
# 0                            NaN                NaN
# 1  UniProtKB unreviewed (TrEMBL)         A0A016ASE6
# 2  UniProtKB unreviewed (TrEMBL)             B6XW19
# 3                       Inactive         A0A173X055
# 4                       Inactive             R7E436
# 5                       Inactive         A0A087AYU9
#
#   0.proteinDescription.submissionNames.0.fullName.evidences.0.evidenceCode  \
# 0                                                NaN
# 1                                        ECO:0000313
# 2                                        ECO:0000313
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   0.proteinDescription.submissionNames.0.fullName.evidences.0.source  \
# 0                                                NaN
# 1                                               EMBL
# 2                                               EMBL
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   0.proteinDescription.submissionNames.0.fullName.evidences.0.id  \
# 0                                                NaN
# 1                                         EXZ31196.1
# 2                                         EEB21138.1
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   0.proteinDescription.submissionNames.0.fullName.value  \
# 0                                                NaN
# 1                            Uncharacterized protein
# 2                            Uncharacterized protein
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   0.extraAttributes.uniParcId 0.inactiveReason.inactiveReasonType  \
# 0                         NaN                                 NaN
# 1               UPI000178838A                                 NaN
# 2               UPI0001846E79                                 NaN
# 3               UPI0003392DA0                             DELETED
# 4               UPI00034054B9                             DELETED
# 5               UPI0005058B1F                             DELETED
#
#   0.inactiveReason.deletedReason
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3             Redundant proteome
# 4             Redundant proteome
# 5             Redundant sequence
