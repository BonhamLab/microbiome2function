# %%
from unirefs_from_genefams import unirefs_from_tsv
from uniprot_parsing import parse_unirefs
import pandas as pd

# %%
genefamilies_file = "/Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/genefam_med_snippet.tsv"

# %%
uniclust2uniref = "/Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/data/mini_uniref_mapping.tsv"

# %%
unirefs = unirefs_from_tsv(genefamilies_file, uniclust2uniref)
# Out:
# 616 UniClust90(s) was/were not matched

# %%
df = parse_unirefs(unirefs, rps=10, batch_size=6)
# Out:
# Processed 0/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4940']
# Dropping and moving on
# Processed 1/223; Querying 6 IDs…
# Processed 2/223; Querying 6 IDs…
# Processed 3/223; Querying 6 IDs…
# Processed 4/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15146']
# Dropping and moving on
# Processed 5/223; Querying 6 IDs…
# Processed 6/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4793']
# Dropping and moving on
# Processed 7/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK13246']
# Dropping and moving on
# Processed 8/223; Querying 6 IDs…
# Processed 9/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4553']
# Dropping and moving on
# Processed 10/223; Querying 6 IDs…
# Processed 11/223; Querying 6 IDs…
# Processed 12/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI00082B9939']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK15311']
# Dropping and moving on
# Processed 13/223; Querying 6 IDs…
# Processed 14/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK6148']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UPI000BA6CD6E']
# Dropping and moving on
# Processed 15/223; Querying 6 IDs…
# Processed 16/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4910']
# Dropping and moving on
# Processed 17/223; Querying 6 IDs…
# Processed 18/223; Querying 6 IDs…
# Processed 19/223; Querying 6 IDs…
# Processed 20/223; Querying 6 IDs…
# Processed 21/223; Querying 6 IDs…
# Processed 22/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK35739']
# Dropping and moving on
# Processed 23/223; Querying 6 IDs…
# Processed 24/223; Querying 6 IDs…
# Processed 25/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK17248']
# Dropping and moving on
# Processed 26/223; Querying 6 IDs…
# Processed 27/223; Querying 6 IDs…
# Processed 28/223; Querying 6 IDs…
# Processed 29/223; Querying 6 IDs…
# Processed 30/223; Querying 6 IDs…
# Processed 31/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41663']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK41490']
# Dropping and moving on
# Processed 32/223; Querying 6 IDs…
# Processed 33/223; Querying 6 IDs…
# Processed 34/223; Querying 6 IDs…
# Processed 35/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15292']
# Dropping and moving on
# Processed 36/223; Querying 6 IDs…
# Processed 37/223; Querying 6 IDs…
# Processed 38/223; Querying 6 IDs…
# Processed 39/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4675']
# Dropping and moving on
# Processed 40/223; Querying 6 IDs…
# Processed 41/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK5077']
# Dropping and moving on
# Processed 42/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4547']
# Dropping and moving on
# Processed 43/223; Querying 6 IDs…
# Processed 44/223; Querying 6 IDs…
# Processed 45/223; Querying 6 IDs…
# Processed 46/223; Querying 6 IDs…
# Processed 47/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI000A021112']
# Dropping and moving on
# Processed 48/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15346']
# Dropping and moving on
# Processed 49/223; Querying 6 IDs…
# Processed 50/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4930']
# Dropping and moving on
# Processed 51/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4761']
# Dropping and moving on
# Processed 52/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK14845']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK63300']
# Dropping and moving on
# Processed 53/223; Querying 6 IDs…
# Processed 54/223; Querying 6 IDs…
# Processed 55/223; Querying 6 IDs…
# Processed 56/223; Querying 6 IDs…
# Processed 57/223; Querying 6 IDs…
# Processed 58/223; Querying 6 IDs…
# Processed 59/223; Querying 6 IDs…
# Processed 60/223; Querying 6 IDs…
# Processed 61/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15074']
# Dropping and moving on
# Processed 62/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK5075']
# Dropping and moving on
# Processed 63/223; Querying 6 IDs…
# Processed 64/223; Querying 6 IDs…
# Processed 65/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK102264']
# Dropping and moving on
# Processed 66/223; Querying 6 IDs…
# Processed 67/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15108']
# Dropping and moving on
# Processed 68/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4939']
# Dropping and moving on
# Processed 69/223; Querying 6 IDs…
# Processed 70/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK28613']
# Dropping and moving on
# Processed 71/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15315']
# Dropping and moving on
# Processed 72/223; Querying 6 IDs…
# Processed 73/223; Querying 6 IDs…
# Processed 74/223; Querying 6 IDs…
# Processed 75/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI0009E3FA94']
# Dropping and moving on
# Processed 76/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK1860']
# Dropping and moving on
# Processed 77/223; Querying 6 IDs…
# Processed 78/223; Querying 6 IDs…
# Processed 79/223; Querying 6 IDs…
# Processed 80/223; Querying 6 IDs…
# Processed 81/223; Querying 6 IDs…
# Processed 82/223; Querying 6 IDs…
# Processed 83/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK36953']
# Dropping and moving on
# Processed 84/223; Querying 6 IDs…
# Processed 85/223; Querying 6 IDs…
# Processed 86/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI0009FB01C4']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK51590']
# Dropping and moving on
# Processed 87/223; Querying 6 IDs…
# Processed 88/223; Querying 6 IDs…
# Processed 89/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK102314']
# Dropping and moving on
# Processed 90/223; Querying 6 IDs…
# Processed 91/223; Querying 6 IDs…
# Processed 92/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI0009B2FA39']
# Dropping and moving on
# Processed 93/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41451']
# Dropping and moving on
# Processed 94/223; Querying 6 IDs…
# Processed 95/223; Querying 6 IDs…
# Processed 96/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41621']
# Dropping and moving on
# Processed 97/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41588']
# Dropping and moving on
# Processed 98/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI00068E78F9']
# Dropping and moving on
# Processed 99/223; Querying 6 IDs…
# Processed 100/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK63299']
# Dropping and moving on
# Processed 101/223; Querying 6 IDs…
# Processed 102/223; Querying 6 IDs…
# Processed 103/223; Querying 6 IDs…
# Processed 104/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK37162']
# Dropping and moving on
# Processed 105/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41609']
# Dropping and moving on
# Processed 106/223; Querying 6 IDs…
# Processed 107/223; Querying 6 IDs…
# Processed 108/223; Querying 6 IDs…
# Processed 109/223; Querying 6 IDs…
# Processed 110/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4948']
# Dropping and moving on
# Processed 111/223; Querying 6 IDs…
# Processed 112/223; Querying 6 IDs…
# Processed 113/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI000219FD79']
# Dropping and moving on
# Processed 114/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4422']
# Dropping and moving on
# Processed 115/223; Querying 6 IDs…
# Processed 116/223; Querying 6 IDs…
# Processed 117/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK28778']
# Dropping and moving on
# Processed 118/223; Querying 6 IDs…
# Processed 119/223; Querying 6 IDs…
# Processed 120/223; Querying 6 IDs…
# Processed 121/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK66068']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK72437']
# Dropping and moving on
# Processed 122/223; Querying 6 IDs…
# Processed 123/223; Querying 6 IDs…
# Processed 124/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41480']
# Dropping and moving on
# Processed 125/223; Querying 6 IDs…
# Processed 126/223; Querying 6 IDs…
# Processed 127/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4950']
# Dropping and moving on
# Processed 128/223; Querying 6 IDs…
# Processed 129/223; Querying 6 IDs…
# Processed 130/223; Querying 6 IDs…
# Processed 131/223; Querying 6 IDs…
# Processed 132/223; Querying 6 IDs…
# Processed 133/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK14807']
# Dropping and moving on
# Processed 134/223; Querying 6 IDs…
# Processed 135/223; Querying 6 IDs…
# Processed 136/223; Querying 6 IDs…
# Processed 137/223; Querying 6 IDs…
# Processed 138/223; Querying 6 IDs…
# Processed 139/223; Querying 6 IDs…
# Processed 140/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK25497']
# Dropping and moving on
# Processed 141/223; Querying 6 IDs…
# Processed 142/223; Querying 6 IDs…
# Processed 143/223; Querying 6 IDs…
# Processed 144/223; Querying 6 IDs…
# Processed 145/223; Querying 6 IDs…
# Processed 146/223; Querying 6 IDs…
# Processed 147/223; Querying 6 IDs…
# Processed 148/223; Querying 6 IDs…
# Processed 149/223; Querying 6 IDs…
# Processed 150/223; Querying 6 IDs…
# Processed 151/223; Querying 6 IDs…
# Processed 152/223; Querying 6 IDs…
# Processed 153/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41664']
# Dropping and moving on
# Processed 154/223; Querying 6 IDs…
# Processed 155/223; Querying 6 IDs…
# Processed 156/223; Querying 6 IDs…
# Processed 157/223; Querying 6 IDs…
# Processed 158/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK5270']
# Dropping and moving on
# Processed 159/223; Querying 6 IDs…
# Processed 160/223; Querying 6 IDs…
# Processed 161/223; Querying 6 IDs…
# Processed 162/223; Querying 6 IDs…
# Processed 163/223; Querying 6 IDs…
# Processed 164/223; Querying 6 IDs…
# Processed 165/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK37113']
# Dropping and moving on
# Processed 166/223; Querying 6 IDs…
# Processed 167/223; Querying 6 IDs…
# Processed 168/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI000A058459']
# Dropping and moving on
# Processed 169/223; Querying 6 IDs…
# Processed 170/223; Querying 6 IDs…
# Processed 171/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15326']
# Dropping and moving on
# Processed 172/223; Querying 6 IDs…
# Processed 173/223; Querying 6 IDs…
# Processed 174/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15301']
# Dropping and moving on
# Processed 175/223; Querying 6 IDs…
# Processed 176/223; Querying 6 IDs…
# Processed 177/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK1814']
# Dropping and moving on
# Processed 178/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41437']
# Dropping and moving on
# Processed 179/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15333']
# Dropping and moving on
# Processed 180/223; Querying 6 IDs…
# Processed 181/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41496']
# Dropping and moving on
# Processed 182/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15332']
# Dropping and moving on
# Processed 183/223; Querying 6 IDs…
# Processed 184/223; Querying 6 IDs…
# Processed 185/223; Querying 6 IDs…
# Processed 186/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4832']
# Dropping and moving on
# Processed 187/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK74356']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK36997']
# Dropping and moving on
# Processed 188/223; Querying 6 IDs…
# Processed 189/223; Querying 6 IDs…
# Processed 190/223; Querying 6 IDs…
# Processed 191/223; Querying 6 IDs…
# Processed 192/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK15052']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK41446']
# Dropping and moving on
# Processed 193/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41586']
# Dropping and moving on
# Processed 194/223; Querying 6 IDs…
# Processed 195/223; Querying 6 IDs…
# Processed 196/223; Querying 6 IDs…
# Processed 197/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4829']
# Dropping and moving on
# ❌ Couldn't retrieve data for ['UNK4963']
# Dropping and moving on
# Processed 198/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK41875']
# Dropping and moving on
# Processed 199/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UPI00047DEDE8']
# Dropping and moving on
# Processed 200/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4673']
# Dropping and moving on
# Processed 201/223; Querying 6 IDs…
# Processed 202/223; Querying 6 IDs…
# Processed 203/223; Querying 6 IDs…
# Processed 204/223; Querying 6 IDs…
# Processed 205/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4949']
# Dropping and moving on
# Processed 206/223; Querying 6 IDs…
# Processed 207/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4909']
# Dropping and moving on
# Processed 208/223; Querying 6 IDs…
# Processed 209/223; Querying 6 IDs…
# Processed 210/223; Querying 6 IDs…
# Processed 211/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK1836']
# Dropping and moving on
# Processed 212/223; Querying 6 IDs…
# Processed 213/223; Querying 6 IDs…
# Processed 214/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK5083']
# Dropping and moving on
# Processed 215/223; Querying 6 IDs…
# Processed 216/223; Querying 6 IDs…
# Processed 217/223; Querying 6 IDs…
# Processed 218/223; Querying 6 IDs…
# Processed 219/223; Querying 6 IDs…
# Processed 220/223; Querying 6 IDs…
# Processed 221/223; Querying 6 IDs…
# ❌ Couldn't retrieve data for ['UNK4877']
# Dropping and moving on
# Processed 222/223; Querying 4 IDs…
# ❌ Couldn't retrieve data for ['UNK4871']
# Dropping and moving on

# %%
df
# Out:
#            Entry                                        Domain [FT]  \
# 0     A0A1E9DKM7
# 1         R6KBL6  DOMAIN 1..120; /note="Thioredoxin"; /evidence=...
# 2         C7GAD9
# 3     A0A0I9UMR7
# 4     A0A1H7X6W4
# ...          ...                                                ...
# 1242      D4V3P0
# 1243  A0A350VIP2
# 1244  A0A173URS8  DOMAIN 294..383; /note="Peptidase S11 D-Ala-D-...
# 1245      D4MZM7
# 1246      E6LQW1  DOMAIN 7..118; /note="Acyl-CoA dehydrogenase/o...
#
#      Domain [CC]                              Protein families  \
# 0
# 1                     Peroxiredoxin family, BCP/PrxQ subfamily
# 2                                             HisA/HisF family
# 3
# 4
# ...          ...                                           ...
# 1242
# 1243
# 1244                                      Peptidase S11 family
# 1245              Glycosyltransferase 4 family, MraY subfamily
# 1246                             Acyl-CoA dehydrogenase family
#
#                      Gene Ontology (molecular function)  \
# 0
# 1          thioredoxin peroxidase activity [GO:0008379]
# 2     1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino...
# 3
# 4
# ...                                                 ...
# 1242
# 1243
# 1244  serine-type D-Ala-D-Ala carboxypeptidase activ...
# 1245  metal ion binding [GO:0046872]; phospho-N-acet...
# 1246  acyl-CoA dehydrogenase activity [GO:0003995]; ...
#
#                      Gene Ontology (biological process) Interacts with  \
# 0
# 1     cell redox homeostasis [GO:0045454]; cellular ...
# 2     L-histidine biosynthetic process [GO:0000105];...
# 3
# 4
# ...                                                 ...            ...
# 1242
# 1243
# 1244  cell wall organization [GO:0071555]; peptidogl...
# 1245  cell wall macromolecule biosynthetic process [...
# 1246
#
#                                           Function [CC]  \
# 0
# 1     FUNCTION: Thiol-specific peroxidase that catal...
# 2
# 3
# 4
# ...                                                 ...
# 1242
# 1243
# 1244  FUNCTION: Removes C-terminal D-alanyl residues...
# 1245
# 1246
#
#                                      Catalytic activity  EC number  \
# 0
# 1     CATALYTIC ACTIVITY: Reaction=a hydroperoxide +...  1.11.1.24
# 2
# 3
# 4
# ...                                                 ...        ...
# 1242
# 1243
# 1244  CATALYTIC ACTIVITY: Reaction=Preferential clea...   3.4.16.4
# 1245                                                      2.7.8.13
# 1246
#
#                                                 Pathway     Rhea ID  \
# 0
# 1                                                        RHEA:62620
# 2     PATHWAY: Amino-acid biosynthesis. {ECO:0000256...
# 3
# 4
# ...                                                 ...         ...
# 1242
# 1243
# 1244  PATHWAY: Cell wall biogenesis; peptidoglycan b...
# 1245
# 1246
#
#                                                Cofactor Activity regulation
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...                 ...
# 1242
# 1243
# 1244
# 1245  COFACTOR: Name=Mg(2+); Xref=ChEBI:CHEBI:18420;...
# 1246  COFACTOR: Name=FAD; Xref=ChEBI:CHEBI:57692; Ev...
#
# [1247 rows x 14 columns]

# %%
df.columns.to_list()
# Out:
# ['Entry',
#  'Domain [FT]',
#  'Domain [CC]',
#  'Protein families',
#  'Gene Ontology (molecular function)',
#  'Gene Ontology (biological process)',
#  'Interacts with',
#  'Function [CC]',
#  'Catalytic activity',
#  'EC number',
#  'Pathway',
#  'Rhea ID',
#  'Cofactor',
#  'Activity regulation']

# %%
list(df["Entry"].values)
# Out:
# ['A0A1E9DKM7',
#  'R6KBL6',
#  'C7GAD9',
#  'A0A0I9UMR7',
#  'A0A1H7X6W4',
#  'A0A2S1VVY1',
#  'A0A084JHL5',
#  'A0A3C1WSL6',
#  'A0A174F735',
#  'A0A175A3G6',
#  'R5V637',
#  'C7H695',
#  'A0A0M6WS83',
#  'A0A0P0M2X6',
#  'I9QR19',
#  'C7GAU0',
#  'A0A3R3Z605',
#  'A6L048',
#  'C7GFH2',
#  'A0A1C6AUC7',
#  'A0A174CBI4',
#  'A0A0M1W9B9',
#  'A0A0P0EST8',
#  'C7G9L0',
#  'D4IN62',
#  'K1RPC7',
#  'A0A174QXS4',
#  'R5I0S0',
#  'B1XJJ2',
#  'B7AU88',
#  'C0FRZ2',
#  'C7G7F0',
#  'A0A173UZ68',
#  'A0A3D0FF81',
#  'B0NI25',
#  'A0A3D2K740',
#  'A6KZL1',
#  'A0A173UR21',
#  'A0A381HRM2',
#  'K1TYT4',
#  'B5CWY4',
#  'A0A0M6WSG6',
#  'R9IFF8',
#  'A0A174KP22',
#  'A0A3D0PT58',
#  'R9I6I5',
#  'B0NJQ4',
#  'A0A3C2BDC7',
#  'A0A380ZJL8',
#  'A0A381HD84',
#  'A0A0P0LFG9',
#  'A0A0E9G982',
#  'A0A351TS15',
#  'A0A173T1K9',
#  'A0A173UV82',
#  'Q8A466',
#  'A0A1C6DHB4',
#  'A0A174YD05',
#  'E0RVS6',
#  'A0A174X6T5',
#  'D4IN87',
#  'A0A1G0XQ53',
#  'A0A0M6WRZ6',
#  'A0A1C6EMP7',
#  'D4IN76',
#  'D4K8W4',
#  'J7Q6B1',
#  'A0A173VB49',
#  'A0A3D4EE06',
#  'E6UD07',
#  'A0A174EK70',
#  'A0A173RVW5',
#  'A5ZWV4',
#  'K1S5G1',
#  'A0A174VS30',
#  'A0A174XE14',
#  'A0A358LK07',
#  'A0A174NPN6',
#  'A0A349BZY7',
#  'B0NCC2',
#  'A0A174AZC8',
#  'Q8A4V8',
#  'E0RYC3',
#  'C7H760',
#  'A0A0M6WAK9',
#  'A0A0P0M1U1',
#  'D4IN85',
#  'A0A174EZX9',
#  'A0A0P0M495',
#  'A0A3R3F0K2',
#  'C7GAJ7',
#  'A0A096KU04',
#  'A0A174H5M7',
#  'A0A1E3AVX1',
#  'I8WJW3',
#  'A0A174DVM4',
#  'A0A0T9GS82',
#  'D4KJY8',
#  'A0A0D0SAW6',
#  'A9KLF1',
#  'D4M2T9',
#  'G2T2M7',
#  'A0A174M590',
#  'A0A3C1XNU5',
#  'Q8A474',
#  'A0A3D1LB50',
#  'E7GJG9',
#  'D8GUM3',
#  'A0A173ZKV3',
#  'A0A353MRS9',
#  'A0A3E2WYF6',
#  'K1UJ58',
#  'A0A174DY56',
#  'C7GAV0',
#  'A0A015V1Z3',
#  'C3RA04',
#  'E2ZFL7',
#  'A0A174KFX8',
#  'C7GF80',
#  'A0A351URQ5',
#  'A0A173VRK7',
#  'K5ZY28',
#  'C0FTS6',
#  'C7G9R5',
#  'E6SPG5',
#  'A0A377U6C6',
#  'R6UTP8',
#  'A0A173URT3',
#  'A0A174EBC4',
#  'D4IMY9',
#  'A0A0P0LFC2',
#  'A0A1C5S3Q7',
#  'A0A0I1JBI8',
#  'C0FMT1',
#  'C0FZD8',
#  'A0A0P0EXQ3',
#  'A0A1C5VTJ0',
#  'G5SRA5',
#  'A0A173UQG7',
#  'A0A174USI8',
#  'A0A172E9U8',
#  'A0A1C5RD16',
#  'A0A0D0QP30',
#  'A6KXA8',
#  'A0A174C4K7',
#  'A0A3D5TB22',
#  'C7G7B3',
#  'A0A078PRK1',
#  'A0A174TIK5',
#  'A0A413WVW1',
#  'A0A174BGH2',
#  'D4IN82',
#  'J9FYM2',
#  'A0A174XPV5',
#  'A0A380KCG9',
#  'R6VCJ4',
#  'P20458',
#  'A0A174DZQ1',
#  'A0A0N7J708',
#  'A0A3D2EH48',
#  'K6B4E2',
#  'A0A330I2M9',
#  'A0A0N7J6L4',
#  'A0A173VU55',
#  'A0A0A0I213',
#  'A0A3A8ZC70',
#  'K7ZQ45',
#  'A0A1C6EFW6',
#  'Q5L8D1',
#  'A0A174CL23',
#  'A0A173RGN5',
#  'A0A1C6APA0',
#  'A0A1C5RKG8',
#  'A0A116MR50',
#  'D4IN72',
#  'A0A1H4DGY6',
#  'D4VA03',
#  'A0A373XNF3',
#  'A0A173TKN2',
#  'A0A1C5RJH2',
#  'A0A143XYT9',
#  'A0A173WDM7',
#  'F3PNI2',
#  'G2SYT0',
#  'A6L050',
#  'C0FP32',
#  'C7G8P8',
#  'C7GEA5',
#  'A0A0P0M5L8',
#  'A0A1C6E0N2',
#  'C7H875',
#  'R7BJE4',
#  'A0A414RN76',
#  'C7G7Q3',
#  'B0NBT0',
#  'B9YBY3',
#  'A0A1C6IRH0',
#  'Q6BF25',
#  'A0A174CSI8',
#  'D4K033',
#  'A0A174Y3E3',
#  'A0A0P0LAN9',
#  'A0A1C5VDV1',
#  'A0A348V7N6',
#  'A0A1C5QQS2',
#  'A0A449PM13',
#  'R5PKN0',
#  'Q8AAN9',
#  'A0A1C5NCJ8',
#  'A0A1C5THK1',
#  'A0A367FVW7',
#  'B3C6C9',
#  'A0A1C6KG13',
#  'K1TRS1',
#  'A0A1Q6J5V5',
#  'D6D3M3',
#  'A0A2X2UY24',
#  'A0A3D1NZM1',
#  'A0A173T610',
#  'A0A3D2IQR9',
#  'A0A173VDR1',
#  'D4IN34',
#  'A0A015V6F7',
#  'F9ZAG2',
#  'A0A0T9AEG2',
#  'A0A173XVA2',
#  'B0NPK8',
#  'C7GB12',
#  'A0A0P6A5J3',
#  'C7GGM5',
#  'A0A355YMZ7',
#  'C7G5K6',
#  'K1U4Q6',
#  'A0A174MFK2',
#  'F9ZAX4',
#  'U2EDC2',
#  'A0A173URQ1',
#  'A0A0U5NUJ2',
#  'A0A174W657',
#  'A0A2X2UZ29',
#  'A0A173VY66',
#  'B5CX02',
#  'D4VA46',
#  'K5ZAS8',
#  'A0A0E9F4R9',
#  'A0A174XIV3',
#  'A0A1C5MY15',
#  'A0A1C5U2D1',
#  'J7R8X5',
#  'A0A078RGM4',
#  'A0A108TDE6',
#  'A0A174Z701',
#  'A0A1C5T5V3',
#  'A0A173V9L0',
#  'A0A0X8VDQ7',
#  'A0A174ELB5',
#  'F4BP65',
#  'A0A2A5TC22',
#  'A0A1C5ZYJ3',
#  'A0A413LYI9',
#  'D4J385',
#  'Q8A612',
#  'D4KXJ5',
#  'D4LI55',
#  'K5ZAT5',
#  'R9KKQ8',
#  'A0A173WXG6',
#  'A0A1C5UE86',
#  'A0A3E4N769',
#  'A0A1V4J2Z5',
#  'A0A3C1CEU7',
#  'A0A0P0GH65',
#  'A0A380IAX5',
#  'R5HP50',
#  'A0A354IDB7',
#  'A5ZWS1',
#  'D4V3I0',
#  'D4IN42',
#  'A0A1C5KVH7',
#  'C0QFR6',
#  'A0A371JBL9',
#  'R5UQZ9',
#  'S3BTB6',
#  'C7G9J8',
#  'A6BEH4',
#  'A0A174QN43',
#  'A0A015TTT0',
#  'F3PV94',
#  'A0A173ZKP0',
#  'A0A3A9FD93',
#  'C7GFP3',
#  'A0A0P0L5L2',
#  'A0A3E4JGB9',
#  'A0A174R939',
#  'A6LEJ5',
#  'A0A174DTK3',
#  'A0A0L7D2I3',
#  'A0A1C6FJ25',
#  'D4IN61',
#  'G1UL89',
#  'A6L070',
#  'A0A396F6Z2',
#  'A0A174HW30',
#  'B0NKP8',
#  'A0A416JL18',
#  'G1UL74',
#  'C0FVU7',
#  'C7G6M3',
#  'A0A1C6K566',
#  'A0A173T0U6',
#  'A0A174CYK5',
#  'A8S071',
#  'A0A1C6HWB7',
#  'A0A1C5TKK5',
#  'B0MUR0',
#  'A0A2H5ZA16',
#  'C7GH59',
#  'A0A174D076',
#  'Q8A0Z8',
#  'A0A1E3AY14',
#  'A0A1C5ZWX5',
#  'A0A1C5SX72',
#  'A0A1Y3RU59',
#  'A0A425VV24',
#  'A0A354CJA8',
#  'A0A1C5UWJ2',
#  'Q64WK7',
#  'A0A0M6X1G1',
#  'A0A174A7R1',
#  'D4KJS2',
#  'C0FV43',
#  'C7GB32',
#  'A0A0N7J738',
#  'K1RN60',
#  'A0A173VS10',
#  'C3REB0',
#  'K1S2D2',
#  'A0A417LQA8',
#  'A7B1P5',
#  'C7GGN2',
#  'A0A2X3VMV0',
#  'A0A0M6W8Z6',
#  'A0A447DSX8',
#  'T2HYV1',
#  'C0FS44',
#  'A0A1I7I2G1',
#  'D4KBL3',
#  'A0A174CSE7',
#  'F5RNA3',
#  'A0A1C5VNR9',
#  'C0G007',
#  'R9I7S4',
#  'A0A1C5P4Q4',
#  'A0A173YBN2',
#  'A0A0D0SF16',
#  'C7G5Y0',
#  'D4K1V8',
#  'A0A0T9XRE3',
#  'A0A174EF44',
#  'A0A3B8XV32',
#  'F3PNT6',
#  'J9FV23',
#  'A0A3D4DWT4',
#  'A0A1C5V2F4',
#  'D4IN83',
#  'A0A3D0HLL6',
#  'E0S0T2',
#  'A0A0A5FSI7',
#  'A0A174DYK9',
#  'A0A395VB58',
#  'A0A174F845',
#  'C7G973',
#  'D4LR54',
#  'A0A0T9GXS0',
#  'A6KYK4',
#  'A0A143XEM3',
#  'A0A174CSB9',
#  'R7K3P7',
#  'R7KL80',
#  'Q8A129',
#  'A0A0N7J805',
#  'C7GER0',
#  'T0TJJ2',
#  'A0A359MSR5',
#  'A0A1H7MQV0',
#  'C7GAQ5',
#  'A0A0P0M569',
#  'D4KNQ8',
#  'A0A0J1FZ64',
#  'A0A3D2GAR5',
#  'A0A0M6WTP8',
#  'A0A0M4RK64',
#  'A0A1E3AQL8',
#  'A0A173T1U6',
#  'A0A1C6FWH6',
#  'Q5LI34',
#  'D4S1Z8',
#  'B5CX33',
#  'A0A192CDZ5',
#  'B3CCI6',
#  'D4KLA6',
#  'A0A174M501',
#  'A0A173UNF6',
#  'A0A173WCS8',
#  'A0A173VH24',
#  'C7H1W5',
#  'A0A351UX82',
#  'C7GCB1',
#  'C7GD45',
#  'F7JJI5',
#  'Q45138',
#  'A0A140DML5',
#  'A0A0B0QJY0',
#  'A0A412MGJ1',
#  'C7G8V1',
#  'A0A1B0FD86',
#  'A0A0N7J6T6',
#  'A0A174BNQ1',
#  'K1TDG6',
#  'A0A373IQH9',
#  'E7H034',
#  'R5BEE7',
#  'C4ZAP4',
#  'U6RBT0',
#  'A0A173UNW2',
#  'A0A417S9B9',
#  'K5ZFY8',
#  'A0A0T9HFC0',
#  'C6ZA63',
#  'C7G774',
#  'E5X4A4',
#  'C0FQJ9',
#  'A0A0N7J6Z0',
#  'A0A3D0HMJ0',
#  'C7G886',
#  'A0A0M6X0A2',
#  'A0A173UCK7',
#  'A0A173VLT5',
#  'A0A414JJI5',
#  'C7GA66',
#  'A0A174CY02',
#  'A0A0P0M1N2',
#  'C4IL18',
#  'A0A0P0L6T2',
#  'A0A1C5KR88',
#  'A0A330HZM5',
#  'A0A3C1J1L0',
#  'A0A173UKA6',
#  'C7G927',
#  'R9I498',
#  'A0A0J2CWG5',
#  'J9F8X8',
#  'A0A1L4J3Y0',
#  'S0FB86',
#  'A0A350J958',
#  'A0A174TQR4',
#  'A0A3D3J2X8',
#  'A0A3B9CGX0',
#  'R5IPC6',
#  'A0A173UPE2',
#  'A0A412VD16',
#  'C7GFE3',
#  'Q9F6U0',
#  'A0A173YKN4',
#  'B7AU45',
#  'A0A1E9DL98',
#  'R9IGK7',
#  'A8SCB8',
#  'J7QY55',
#  'A0A174HMZ2',
#  'K1RBT1',
#  'E0RW75',
#  'E6LSJ0',
#  'A0A2X0Z9G3',
#  'A0A3P8MBK9',
#  'C6ZBE6',
#  'C7GAA4',
#  'A0A0M6WI96',
#  'A0A173RZE9',
#  'K1RHG7',
#  'Q8A470',
#  'P0CF79',
#  'A0A0P0LKX6',
#  'A0A173T3W8',
#  'A0A373NAD8',
#  'A5Z9J9',
#  'A0A173UV04',
#  'A0A174P4L7',
#  'A0A1Q6H6K4',
#  'A0A173WQW0',
#  'A0A0U5PD29',
#  'A0A174G643',
#  'A0A1R4B5R7',
#  'U6RBF3',
#  'F7LT77',
#  'A0A174DT76',
#  'A0A3C0HVZ6',
#  'A0A1C5U1X8',
#  'A0A1C6EAS7',
#  'A0A173U4H9',
#  'D4IN67',
#  'A0A2W0CL51',
#  'I9J2Y0',
#  'A0A173S638',
#  'A0A227LFQ8',
#  'A0A174XTF6',
#  'A0A2B2BTK7',
#  'A0A173ZQ47',
#  'A0A174PMJ1',
#  'A0A0M6WCR6',
#  'C7G5M7',
#  'A0A143XZN8',
#  'C0FPL9',
#  'K1TN49',
#  'A0A174DDT2',
#  'K1T475',
#  'C6IM92',
#  'A6KZP0',
#  'A0A174CMY4',
#  'D2MN49',
#  'A0A0P0M1E3',
#  'A0A0M6W9V3',
#  'A0A0M6WTR7',
#  'A0A1C5QPZ3',
#  'E5V0K3',
#  'C7GDY1',
#  'C0FNC3',
#  'A0A174CTW6',
#  'B4UUJ4',
#  'A0A174T5N3',
#  'A0A2N2AID2',
#  'A0A173TFT2',
#  'A0A174EMZ8',
#  'A0A1E3AIJ4',
#  'A0A173RJ58',
#  'D4KLR4',
#  'A0A174CGA7',
#  'A0A0D0RIS0',
#  'R6LCI8',
#  'D4IN81',
#  'A0A2T0AXR0',
#  'Q89ZG0',
#  'D4MXX9',
#  'I8WTE3',
#  'A0A352CRS9',
#  'Q8A0Z4',
#  'E2N7J8',
#  'A0A1C5KY92',
#  'A0A174MHV6',
#  'D4L1L6',
#  'A0A068YTY8',
#  'A0A173Z9C0',
#  'A0A3R5ZG63',
#  'C7GEN3',
#  'J7TG29',
#  'A0A174GJK5',
#  'D4IN70',
#  'I7LCB9',
#  'C7GAW3',
#  'C7GBL2',
#  'A0A0K9CP99',
#  'A0A174IQU9',
#  'A7LT11',
#  'O34512',
#  'A0A173SFU6',
#  'A0A174JU45',
#  'A0A0F7Q4K3',
#  'A0A174V9B0',
#  'D4IN79',
#  'A0A076IUE9',
#  'A0A3E4N512',
#  'B5CWZ9',
#  'A0A0U5PG50',
#  'A0A3D3U7C1',
#  'A0A413ME05',
#  'A0A173V854',
#  'C4ZFE2',
#  'B6FSS9',
#  'A0A173U7U4',
#  'F3PNT2',
#  'C0FQD4',
#  'D4IN77',
#  'A0A174EWZ8',
#  'D6DY89',
#  'A0A1C5R451',
#  'A0A174CG43',
#  'A0A239ZFH1',
#  'S3BKL8',
#  'A0A1E3A9X8',
#  'R9HJV9',
#  'R9HAW9',
#  'A0A1C5TLF8',
#  'C7GD78',
#  'E2ZIJ6',
#  'C7HSH5',
#  'A0A1H0C4R3',
#  'A0A173S0X1',
#  'D4LTT9',
#  'A6LGZ7',
#  'K1SHX5',
#  'A0A0M6WKA4',
#  'K2MEN0',
#  'R7AML3',
#  'C7G751',
#  'I8WCD4',
#  'A0A354DL82',
#  'K1UJY1',
#  'A0A3E5EXI6',
#  'A0A446G6M8',
#  'A0A3C0ZWS8',
#  'K7ZRU6',
#  'A0A173WK22',
#  'K1SLW5',
#  'A0A1C5VKB4',
#  'A0A173U254',
#  'D9SNA4',
#  'K1SKC1',
#  'A0A174I5P4',
#  'C7G7B5',
#  'D4KXW4',
#  'A6L083',
#  'A0A354D3Y4',
#  'A0A060CSJ6',
#  'A0A1C6FRX4',
#  'A0A1D4L7P2',
#  'A0A395ZXJ1',
#  'A5ZAA5',
#  'A0A395VPC4',
#  'B4UUJ5',
#  'A0A2A6ZEJ6',
#  'B5CSX9',
#  'C4Z9C9',
#  'C7GAM3',
#  'K1T670',
#  'C7GGD0',
#  'A0A174BU74',
#  'Q8A488',
#  'A0A2A7ACK4',
#  'C4ZF41',
#  'A0A1C6C4U4',
#  'A0A174B5X0',
#  'R9M731',
#  'A0A173VU48',
#  'G2T4H6',
#  'J9FB23',
#  'R9I528',
#  'X8GUR1',
#  'A0A087AWS4',
#  'C7GDS6',
#  'A0A173UUI7',
#  'A0A1C5ZWQ2',
#  'A0A412XSJ8',
#  'U2E7L3',
#  'C1P5Z8',
#  'A0A076IX29',
#  'K4LDQ5',
#  'A0A1C5MX24',
#  'C7GHK5',
#  'A0A173WNZ6',
#  'A0A1Y4TZ46',
#  'U2DSB7',
#  'U6RBB2',
#  'A0A447DSP2',
#  'F7LRN8',
#  'T4BYJ4',
#  'R5B2I6',
#  'A0A0F0CNF7',
#  'A0A0M6W939',
#  'Q5CZE8',
#  'A0A3F3S4F8',
#  'D4J287',
#  'A0A1C5VDS1',
#  'A0A1C6H739',
#  'A0A1D7PYT2',
#  'A0A255ISC8',
#  'A0A349QQF1',
#  'A0A173UWL4',
#  'F3PV93',
#  'A0A352WE59',
#  'A0A381HHX0',
#  'A0A3R7CG79',
#  'A0A0P0LMH0',
#  'C7G971',
#  'A0A174V1A4',
#  'K1TU43',
#  'A0A1H7REQ9',
#  'K1UEW9',
#  'Q8A0W0',
#  'D4C8E8',
#  'A0A069RJB6',
#  'A0A174CRA6',
#  'A0A3C0WZM9',
#  'A0A1V5Q3D9',
#  'K1T6J2',
#  'A0A351TFB8',
#  'A0A0D0SDV4',
#  'C7GA36',
#  'A0A174WH72',
#  'A0A139LNR0',
#  'C7GCP6',
#  'R9HJW1',
#  'A0A174G5M1',
#  'A0A1H5V577',
#  'A0A350U050',
#  'A0A0P0G5U1',
#  'A0A2C1JXB8',
#  'A0A417PAV7',
#  'A0A173TY65',
#  'A0A1C6E0W5',
#  'A0A0F0CH88',
#  'A0A1I5G9P3',
#  'A0A373KDC9',
#  'B0P1Z4',
#  'D6E0H6',
#  'K4Q8U7',
#  'C0GDM7',
#  'A0A173SBK7',
#  'A0A173V0C7',
#  'A0A0M1IYJ5',
#  'A0A1C6DJB3',
#  'A0A174MDP8',
#  'A0A173U737',
#  'A0A1E3AQS6',
#  'A0A1H3AWX1',
#  'A0A1C5UP33',
#  'A0A1C5QNX6',
#  'A0A350VL76',
#  'A0A174GWM5',
#  'C7H475',
#  'A0A0B7GV04',
#  'A0A1C5PFD7',
#  'D4J4D1',
#  'A0A1F0I2K4',
#  'A6L012',
#  'A0A0P0M1C8',
#  'A0A1C5S3F3',
#  'C7H1W4',
#  'K1UFX9',
#  'A0A174FBG4',
#  'C7GB43',
#  'A0A1C6DL00',
#  'A0A174P1K5',
#  'A0A1C5WED5',
#  'C7GBN4',
#  'A0A174RG04',
#  'A0A3R6S8N3',
#  'R6TUI4',
#  'C7G5A7',
#  'A0A174ISJ1',
#  'C7G901',
#  'R7BP17',
#  'A0A3E5EXX2',
#  'A0A173ZPQ6',
#  'A0A174TB21',
#  'A0A1Z4K3L1',
#  'A7LTR6',
#  'A6LFQ4',
#  'D4IN63',
#  'K4LKL8',
#  'A0A355BHK1',
#  'Q45137',
#  'K9EAM3',
#  'C7G776',
#  'A0A0M6WLI8',
#  'J9GB23',
#  'C7GFB6',
#  'A0A174LPX7',
#  'G4L1N8',
#  'A0A285PVJ3',
#  'A0A0P0FGQ5',
#  'A0A0M6X0U7',
#  'A0A174JH13',
#  'A0A1Q6SWZ9',
#  'D1NFR0',
#  'Q8A482',
#  'A0A174K0A6',
#  'C7G837',
#  'A0A351VBI8',
#  'A0A380ZVH5',
#  'R5WT82',
#  'D4KBJ9',
#  'A0A1H3WAT9',
#  'E9YVF4',
#  'A0A174CR65',
#  'C7GCP1',
#  'A0A1E3A963',
#  'A0A0P0M5V9',
#  'A0A173ZXW9',
#  'A0A139MM45',
#  'V8C708',
#  'D1KAH7',
#  'A0A0M6WDS2',
#  'A0A3R6RUG3',
#  'A0A1Q6TVN5',
#  'I8ZT59',
#  'A0A1C5UCN5',
#  'A0A397WB56',
#  'A0A174T7Z7',
#  'C0FU98',
#  'D1W253',
#  'A0A173WE17',
#  'A0A174HHV4',
#  'B6FNI9',
#  'A0A415SEX3',
#  'A0A174D1E9',
#  'D4K014',
#  'R5KK50',
#  'D4KBC0',
#  'R6BEV7',
#  'F7JJH2',
#  'A0A1C5VX49',
#  'A0A1Q6RMQ0',
#  'C7GE88',
#  'J9FN28',
#  'A0A1S8P371',
#  'C7GD36',
#  'A0A1C5YAR7',
#  'A0A173VNS9',
#  'A0A174EYH9',
#  'A0A3D2K640',
#  'D4IXS6',
#  'A0A0P0LEW6',
#  'A0A174STK3',
#  'J9C8V6',
#  'A0A1C5QX76',
#  'E6SWH0',
#  'D4JKL2',
#  'P0CF66',
#  'F3PNL3',
#  'F9EKQ3',
#  'J9FVB6',
#  'I8ZLF0',
#  'C0BWA8',
#  'C7G5G5',
#  'F8EZV5',
#  'A0A174B3P7',
#  'A0A3N0AN87',
#  'K1UCX4',
#  'A0A1I0X326',
#  'C7G7W2',
#  'C7GCL6',
#  'A0A285PVJ0',
#  'C7GCM1',
#  'A0A0D0QLI0',
#  'A0A174X066',
#  'D5RB70',
#  'A0A1C5Q875',
#  'A0A1C6FIR9',
#  'K9DSU7',
#  'A0A078RIU7',
#  'A0A0K9CMM9',
#  'B2RLW9',
#  'A0A174ZJF4',
#  'E2ZHY0',
#  'A0A414G4R5',
#  'D4IVZ6',
#  'G1UM99',
#  'D4IN92',
#  'C7G701',
#  'S3CF99',
#  'A0A377U3K1',
#  'A0A0M6WM77',
#  'I9FKA5',
#  'A0A174ZWG0',
#  'A0A3R6AIY9',
#  'K1TQH2',
#  'A0A1Y4PCG7',
#  'G4KTF4',
#  'A6KXM7',
#  'A0A0P0M0E8',
#  'A0A173TNT0',
#  'A0A174WP62',
#  'A6NYQ4',
#  'A0A449TP30',
#  'A0A173YBU1',
#  'A0A379UW00',
#  'A0A3N5M649',
#  'A0A0P0M0Z8',
#  'E4TF97',
#  'A0A173VV97',
#  'A0A401M1U1',
#  'C4ZDB7',
#  'C7GEB5',
#  'A0A414F1L8',
#  'A0A0M0N1B3',
#  'A0A174Y3Y2',
#  'A0A174PJU6',
#  'A0A330I649',
#  'E5V0K7',
#  'A0A174CQR6',
#  'A0A173ZA65',
#  'A4NYJ0',
#  'A0A3A8WF10',
#  'A0A354R8A4',
#  'C7GAE0',
#  'C7HVW6',
#  'A0A0T9AFF5',
#  'D4V9Y7',
#  'A0A374N2Z1',
#  'I9EIG0',
#  'A0A0P0F664',
#  'A0A3E4XN06',
#  'R9HYY3',
#  'Q8A481',
#  'G2T0Y1',
#  'A0A173R1U9',
#  'B0G4Y0',
#  'C7G969',
#  'A0A3D5LX04',
#  'C7G5D9',
#  'A0A0P0M5X8',
#  'A0A349YHP4',
#  'D4JRW1',
#  'A0A174QS89',
#  'C6IUF0',
#  'A0A1C5UYS1',
#  'A0A174KR47',
#  'A0A173ZFZ9',
#  'A0A0M6X011',
#  'D4JYZ2',
#  'A0A0M6WF06',
#  'I8ZEG1',
#  'V2Y0E2',
#  'A0A1C5TPN5',
#  'A0A0T8QMR7',
#  'D1K489',
#  'D4IWU8',
#  'A0A1C5MPQ8',
#  'A0A174YPH6',
#  'C7GGM4',
#  'Q8A7B8',
#  'A0A413KES5',
#  'C0FWE6',
#  'C7G6J9',
#  'A0A1G5S2L4',
#  'A0A0P0M3W8',
#  'A0A381JM37',
#  'A0A3B9CDJ0',
#  'Q0ZS24',
#  'A0A1C6B2M0',
#  'A0A1I0M4F4',
#  'A0A174PUX6',
#  'A0A174Y2Z3',
#  'I7KIS9',
#  'A0A174CIE2',
#  'A0A285PV79',
#  'D1VTH3',
#  'A0A173UM04',
#  'A0A174FQE4',
#  'A6KYH2',
#  'A0A173UZA3',
#  'A0A173YKP5',
#  'A0A0I9UMR3',
#  'A0A174X6V0',
#  'E7H033',
#  'D4KUU3',
#  'A0A015W8Z5',
#  'K9DXH5',
#  'C7G924',
#  'A0A174ATB0',
#  'D4KNK5',
#  'A0A173UBT7',
#  'C7GH47',
#  'E5V0L3',
#  'C0FRY1',
#  'A0A0M6WBG3',
#  'A0A174ZC98',
#  'C7G9F0',
#  'C7GF26',
#  'A0A173W1C8',
#  'A0A174JJA2',
#  'C0FX05',
#  'C6PZN0',
#  'D7GTN1',
#  'K1TXI7',
#  'D4IN36',
#  'A0A0P0FSI7',
#  'A0A174WVH0',
#  'A0A174B705',
#  'Q93L62',
#  'C8U7S7',
#  'D4KTQ0',
#  'K5ZY15',
#  'A0A173Y7X4',
#  'A0A173Z4P3',
#  'C7GFF6',
#  'A0A173YR90',
#  'A0A0X8VAR3',
#  'A0A174QZQ2',
#  'C0B7N2',
#  'G2T4D2',
#  'A0A1Y4UGU1',
#  'A0A174QYX1',
#  'D4KLA9',
#  'E2NWJ3',
#  'A0A1C5Z5D9',
#  'A0A2K4ZPP0',
#  'A0A3S4WPF7',
#  'Q8A6M0',
#  'A0A174JUM1',
#  ...]
