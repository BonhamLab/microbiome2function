# %%
from uniprot_parsing import features_from_Uniref90ID

# %%
df = features_from_Uniref90ID("A0A1B0GTW7", "ft_region")

# %%
df
# Out:
#                          entryType primaryAccession comments  \
# 0  UniProtKB reviewed (Swiss-Prot)       A0A1B0GTW7       []
#
#                   extraAttributes
# 0  {'uniParcId': 'UPI0007E52C07'}
