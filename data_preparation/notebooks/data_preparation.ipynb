# %%
# %cd ..
# Out:
# /Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/data_preparation

# %%
import pandas as pd
import data_prep_scripts

# %%
df = pd.read_csv(data_prep_scripts.FETCHED_DATA)

# %%
new_df = data_prep_scripts.process_entries(df)
# Out:
# No preprocessing rule for 'Entry' — leaving as is.

# %% [markdown]
# # Before pre-processing

# %%
cols = df.columns

summary = []
for col in cols:
    non_null = df[col].count()
    unique   = df[col].nunique(dropna=True)
    duplication_rate = (non_null - unique) / non_null if non_null else float("nan")
    summary.append({
        "column": col,
        "dimensionality": unique,
        "% entries sharing it": f"{duplication_rate:.2%}",
        "% non-null": f"{non_null / len(df):.2%}"
    })

summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
#                                 column  dimensionality % entries sharing it  \
# 0                                Entry             263                0.00%
# 1                          Domain [FT]           26047                8.78%
# 2                          Domain [CC]             328               50.15%
# 3                     Protein families            2714               87.84%
# 4   Gene Ontology (molecular function)            6310               83.34%
# 5   Gene Ontology (biological process)            2786               89.00%
# 6                       Interacts with             367                8.93%
# 7                        Function [CC]            4594               56.18%
# 8                   Catalytic activity            3273               72.90%
# 9                            EC number            2580               89.95%
# 10                             Pathway            1529               72.22%
# 11                             Rhea ID            1498               84.44%
# 12                            Cofactor            1344               79.52%
# 13                 Activity regulation             367               21.58%
#
#    % non-null
# 0       0.62%
# 1      67.69%
# 2       1.56%
# 3      52.92%
# 4      89.77%
# 5      60.06%
# 6       0.96%
# 7      24.86%
# 8      28.63%
# 9      60.88%
# 10     13.05%
# 11     22.83%
# 12     15.56%
# 13      1.11%

# %% [markdown]
# # After pre-processing

# %%
cols = new_df.columns

summary = []
for col in cols:
    non_null = new_df[col].count()
    unique   = new_df[col].nunique(dropna=True)
    duplication_rate = (non_null - unique) / non_null if non_null else float("nan")
    summary.append({
        "column": col,
        "dimensionality": unique,
        "% entries sharing it": f"{duplication_rate:.2%}",
        "% non-null": f"{non_null / len(new_df):.2%}"
    })

summary_new_df = pd.DataFrame(summary)
print(summary_new_df)
# Out:
#                                 column  dimensionality % entries sharing it  \
# 0                                Entry             263                0.00%
# 1                          Domain [FT]            3431               87.98%
# 2                          Domain [CC]             278               57.75%
# 3                     Protein families            2702               87.90%
# 4   Gene Ontology (molecular function)            6310               83.34%
# 5   Gene Ontology (biological process)            2786               89.00%
# 6                       Interacts with             367                8.93%
# 7                        Function [CC]            3401               67.56%
# 8                   Catalytic activity            1637               86.44%
# 9                            EC number            2576               89.97%
# 10                             Pathway             632               88.52%
# 11                             Rhea ID            1498               84.44%
# 12                            Cofactor             190               97.10%
# 13                 Activity regulation             341               27.14%
#
#    % non-null
# 0       0.62%
# 1      67.69%
# 2       1.56%
# 3      52.92%
# 4      89.77%
# 5      60.06%
# 6       0.96%
# 7      24.86%
# 8      28.63%
# 9      60.88%
# 10     13.05%
# 11     22.83%
# 12     15.56%
# 13      1.11%

# %%
new_df
# Out:
#         Entry                                        Domain [FT] Domain [CC]  \
# 0         NaN                                                NaN         NaN
# 1         NaN                      (gs beta-grasp, gs catalytic)         NaN
# 2         NaN                                                NaN         NaN
# 3         NaN                                    abc transporter         NaN
# 4         NaN                                                NaN         NaN
# ...       ...                                                ...         ...
# 42174  a6lcg5  (glycosyl hydrolase family 92 n-terminal, glyc...         NaN
# 42175  c4frk5                                                NaN         NaN
# 42176  d4mzc0  (galactokinase n-terminal, ghmp kinase n-termi...         NaN
# 42177  k1tbl3                                           mgs-like         NaN
# 42178  r7qvj6                                                NaN         NaN
#
#                                         Protein families  \
# 0              bacterial solute-binding protein 2 family
# 1                            glutamine synthetase family
# 2      resistance-nodulation-cell division (rnd) (tc ...
# 3              abc transporter superfamily, ycf16 family
# 4      metallo-dependent hydrolases superfamily, tatd...
# ...                                                  ...
# 42174                                                NaN
# 42175                                                NaN
# 42176                 ghmp kinase family, galk subfamily
# 42177                                                NaN
# 42178                                                NaN
#
#                       Gene Ontology (molecular function)  \
# 0                                             go:0048029
# 1      (go:0005524, go:0140297, go:0016595, go:007040...
# 2                   (go:0015125, go:0015562, go:0042910)
# 3                               (go:0005524, go:0016887)
# 4      (go:0000175, go:0004536, go:0000287, go:004687...
# ...                                                  ...
# 42174                           (go:0030246, go:0000224)
# 42175                                                NaN
# 42176                           (go:0005524, go:0004335)
# 42177                                         go:0008929
# 42178                                         go:0016832
#
#                       Gene Ontology (biological process)  \
# 0                   (go:0015752, go:0050918, go:0055085)
# 1      (go:0043562, go:0006542, go:1904797, go:004589...
# 2      (go:0015721, go:0046677, go:0009636, go:014033...
# 3                               (go:0016226, go:0009314)
# 4                                             go:0042542
# ...                                                  ...
# 42174                           (go:0005975, go:0006516)
# 42175                                         go:0009306
# 42176                                         go:0006012
# 42177                                         go:0019242
# 42178                                         go:0005975
#
#                  Interacts with  \
# 0              (p00956, p0agi1)
# 1              (p37582, q45666)
# 2                           NaN
# 3      (p77667, p77522, p77689)
# 4                           NaN
# ...                         ...
# 42174                       NaN
# 42175                       NaN
# 42176                       NaN
# 42177                       NaN
# 42178                       NaN
#
#                                            Function [CC]  \
# 0      part of the abc transporter complex rbsabc inv...
# 1      glutamine synthetase (gs) is an unusual multit...
# 2      participates in the efflux of aminoglycosides....
# 3      has low atpase activity. the sufbcd complex ac...
# 4      3'-5' exonuclease that prefers single-stranded...
# ...                                                  ...
# 42174                                                NaN
# 42175                                                NaN
# 42176                                                NaN
# 42177                                                NaN
# 42178                                                NaN
#
#                                       Catalytic activity  \
# 0                                                    NaN
# 1      l-glutamate + nh4(+) + atp = l-glutamine + adp...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42174                                                NaN
# 42175                                                NaN
# 42176                                                NaN
# 42177                                                NaN
# 42178                                                NaN
#
#                   EC number Pathway Rhea ID          Cofactor  \
# 0                       NaN     NaN     NaN               NaN
# 1                   6.3.1.2     NaN   16169            mg(2+)
# 2                       NaN     NaN     NaN               NaN
# 3                       NaN     NaN     NaN               NaN
# 4      (3.1.11.-, 3.1.13.-)     NaN     NaN  (mg(2+), mn(2+))
# ...                     ...     ...     ...               ...
# 42174                   NaN     NaN     NaN            ca(2+)
# 42175                   NaN     NaN     NaN               NaN
# 42176               2.7.1.6     NaN     NaN               NaN
# 42177                   NaN     NaN     NaN               NaN
# 42178                   NaN     NaN     NaN               NaN
#
#                                      Activity regulation
# 0                                                    NaN
# 1      completely inhibited by glutamine and partiall...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42174                                                NaN
# 42175                                                NaN
# 42176                                                NaN
# 42177                                                NaN
# 42178                                                NaN
#
# [42179 rows x 14 columns]
